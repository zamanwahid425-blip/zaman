# %% [markdown]
# <a href="https://colab.research.google.com/github/zamanwahid425-blip/zaman/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 Internship Task-02 : Data Cleaning & EDA
# Dataset: Titanic (from GitHub)

# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Load Dataset directly from GitHub (no upload needed)
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)

print("✅ Dataset Loaded Successfully")
print("Shape of dataset:", data.shape)

# Basic Exploration
print("\nDataset Info:")
print(data.info())
print("\nFirst 5 rows:")
print(data.head())

# Data Cleaning
print("\nMissing Values Before Cleaning:")
print(data.isnull().sum())

# Fill missing Age with median
data['Age'].fillna(data['Age'].median(), inplace=True)

# Fill missing Embarked with mode
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

# Drop Cabin column (too many missing values)
if 'Cabin' in data.columns:
    data.drop(columns=['Cabin'], inplace=True)

print("\nMissing Values After Cleaning:")
print(data.isnull().sum())

# Summary Statistics
print("\nSummary Statistics:")
print(data.describe(include='all'))

# Exploratory Data Analysis (EDA)

# Survival Count
plt.figure(figsize=(5,4))
sns.countplot(data=data, x='Survived')
plt.title("Survival Count")
plt.show()

# Survival by Gender
plt.figure(figsize=(5,4))
sns.countplot(data=data, x='Survived', hue='Sex')
plt.title("Survival by Gender")
plt.show()

# Survival by Passenger Class
plt.figure(figsize=(5,4))
sns.countplot(data=data, x='Survived', hue='Pclass')
plt.title("Survival by Passenger Class")
plt.show()

# Age Distribution
plt.figure(figsize=(6,4))
sns.histplot(data['Age'], bins=30, kde=True)
plt.title("Age Distribution")
plt.show()

# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# Insights Section (Write in your own words)
print("\n🔎 Sample Insights:")
print("1. Females had higher survival rates than males.")
print("2. Passengers in 1st Class had better survival chances than those in 3rd Class.")
print("3. Younger passengers had slightly better chances of survival.")
# Out:
# ✅ Dataset Loaded Successfully
# Shape of dataset: (891, 12)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# ...
